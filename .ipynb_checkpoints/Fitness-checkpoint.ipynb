# %% [markdown]
# # 1. Importing the Necessary Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pylab 
import scipy.stats as stats

# %% [markdown]
# # 2. Loading the Datasets

# %%
df=pd.read_csv('Data_Sets/DietData.csv')

# %% [markdown]
# # 3. Data exploration and the Initial Inspection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Food_items     159 non-null    object
#  1   Breakfast      159 non-null    int64
#  2   Lunch          159 non-null    int64
#  3   Dinner         159 non-null    int64
#  4   VegNovVeg      159 non-null    int64
#  5   Junk Food      159 non-null    int64
#  6   Calories       159 non-null    int64
#  7   Fats           159 non-null    float64
#  8   Proteins       159 non-null    float64
#  9   Iron           159 non-null    float64
#  10  Calcium        159 non-null    float64
#  11  Sodium         159 non-null    float64
#  12  Potassium      159 non-null    float64
#  13  Carbohydrates  159 non-null    float64
#  14  Fibre          159 non-null    float64
#  15  VitaminD       159 non-null    int64
#  16  Sugars         159 non-null    float64
# dtypes: float64(9), int64(7), object(1)
# memory usage: 21.2+ KB

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.title('Frequency Histogram')
plt.ylabel('Frequency')
plt.xlabel('Bins Center')
ax.hist(df.Calories.to_numpy(),bins=[0,100,200,300,400,500,600,700,800,900,1000,1000,2000,3000,5000],linewidth=0.5, edgecolor="white")
plt.show()

# %%
stats.probplot(df.Calories.to_numpy(), dist="norm", plot=pylab)
pylab.show()

# %%
df.columns
# Out:
# Index(['Food_items', 'Breakfast', 'Lunch', 'Dinner', 'VegNovVeg', 'Junk Food',
#        'Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium',
#        'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars'],
#       dtype='object')

# %%
dataset=df.copy()
columns=['Food_items', 'Breakfast', 'Lunch', 'Dinner', 'VegNovVeg', 'Junk Food',
       'Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium',
       'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars']
dataset=dataset[columns]

# %%
max_calories=2000
max_fats=75
max_proteins=120
max_iron=45
max_calcium=2500
max_sodium=1500
max_potassium=2500
max_carbohydrates=250
max_fibre=30
max_vitaminD=100
max_sugars=50
max_list=[max_calories,max_fats,max_proteins,max_iron,max_calcium,max_sodium,max_potassium,max_carbohydrates,max_fibre,max_vitaminD,max_sugars]

# %%
extracted_data=dataset.copy()
for column,maximum in zip(extracted_data.columns[6:15],max_list):
    extracted_data=extracted_data[extracted_data[column]<maximum]

# %%
extracted_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, 0 to 158
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Food_items     152 non-null    object
#  1   Breakfast      152 non-null    int64
#  2   Lunch          152 non-null    int64
#  3   Dinner         152 non-null    int64
#  4   VegNovVeg      152 non-null    int64
#  5   Junk Food      152 non-null    int64
#  6   Calories       152 non-null    int64
#  7   Fats           152 non-null    float64
#  8   Proteins       152 non-null    float64
#  9   Iron           152 non-null    float64
#  10  Calcium        152 non-null    float64
#  11  Sodium         152 non-null    float64
#  12  Potassium      152 non-null    float64
#  13  Carbohydrates  152 non-null    float64
#  14  Fibre          152 non-null    float64
#  15  VitaminD       152 non-null    int64
#  16  Sugars         152 non-null    float64
# dtypes: float64(9), int64(7), object(1)
# memory usage: 21.4+ KB

# %%
extracted_data.iloc[:,6:15].corr()
# Out:
#                Calories      Fats  Proteins      Iron   Calcium    Sodium  \
# Calories       1.000000  0.745082  0.261837 -0.005583  0.026520  0.272497
# Fats           0.745082  1.000000  0.207073 -0.059743  0.010620  0.207740
# Proteins       0.261837  0.207073  1.000000  0.333684  0.554496  0.084331
# Iron          -0.005583 -0.059743  0.333684  1.000000  0.356321  0.035707
# Calcium        0.026520  0.010620  0.554496  0.356321  1.000000 -0.090607
# Sodium         0.272497  0.207740  0.084331  0.035707 -0.090607  1.000000
# Potassium      0.255963  0.299077  0.209210  0.034412 -0.007796  0.152067
# Carbohydrates  0.726455  0.220375 -0.092455  0.011055 -0.100516  0.150309
# Fibre          0.215880  0.151907 -0.075295 -0.014563 -0.055754  0.025338
#
#                Potassium  Carbohydrates     Fibre
# Calories        0.255963       0.726455  0.215880
# Fats            0.299077       0.220375  0.151907
# Proteins        0.209210      -0.092455 -0.075295
# Iron            0.034412       0.011055 -0.014563
# Calcium        -0.007796      -0.100516 -0.055754
# Sodium          0.152067       0.150309  0.025338
# Potassium       1.000000       0.036969  0.248017
# Carbohydrates   0.036969       1.000000  0.224881
# Fibre           0.248017       0.224881  1.000000

# %%
df.columns

# %% [markdown]
# # 4. Checking the mising values

# %%
df.isnull().sum()
# Out:
# Food_items       0
# Breakfast        0
# Lunch            0
# Dinner           0
# VegNovVeg        0
# Junk Food        0
# Calories         0
# Fats             0
# Proteins         0
# Iron             0
# Calcium          0
# Sodium           0
# Potassium        0
# Carbohydrates    0
# Fibre            0
# VitaminD         0
# Sugars           0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
prep_data=scaler.fit_transform(extracted_data.iloc[:,6:15].to_numpy())

# %%
prep_data
# Out:
# array([[-1.1596288 , -0.79110332, -0.60911244, ...,  0.16650673,
#         -0.83120152, -0.09008631],
#        [-0.29297495,  0.77440163, -0.642676  , ...,  1.34815584,
#         -0.65844138,  1.15474274],
#        [-0.73886207, -0.78052558, -0.71819402, ...,  0.77317715,
#         -0.08911819,  0.06882803],
#        ...,
#        [-0.85190388, -0.48434897, -0.71819402, ..., -0.84762891,
#         -0.62703044, -0.48737218],
#        [ 3.41228428,  2.04372997, -0.05531364, ..., -0.84762891,
#          3.71945758, -0.61980081],
#        [ 0.64904011,  1.09173372, -0.47485818, ..., -0.84762891,
#          0.26425482, -0.35494356]])

# %% [markdown]
# # 5. Trainning the model

# %% [markdown]
# ## a) Fitting the model

# %%
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(metric='cosine',algorithm='brute')
neigh.fit(prep_data)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
transformer = FunctionTransformer(neigh.kneighbors,kw_args={'return_distance':False})
pipeline=Pipeline([('std_scaler',scaler),('NN',transformer)])

# %%
params={'n_neighbors':10,'return_distance':False}
pipeline.get_params()
pipeline.set_params(NN__kw_args=params)
# Out:
# Pipeline(steps=[('std_scaler', StandardScaler()),
#                 ('NN',
#                  FunctionTransformer(func=<bound method KNeighborsMixin.kneighbors of NearestNeighbors(algorithm='brute', metric='cosine')>,
#                                      kw_args={'n_neighbors': 10,
#                                               'return_distance': False}))])

# %%
pipeline.transform(extracted_data.iloc[0:1,6:15].to_numpy())[0]
# Out:
# array([  0, 112,  58,  38,  63,  15,  46,  51,  48,  53], dtype=int64)

# %% [markdown]
# # b) Testing the model

# %%
extracted_data.iloc[pipeline.transform(extracted_data.iloc[0:1,6:15].to_numpy())[0]]
# Out:
#                       Food_items  Breakfast  Lunch  Dinner  VegNovVeg  \
# 0               Asparagus Cooked          0      1       1          0
# 119  Mustard Green(Rayo ko sagg)          0      1       1          0
# 59                         Beans          0      1       1          0
# 38                        Tomato          1      1       1          0
# 64                  Strawberries          1      0       0          0
# 15                        Onions          0      1       1          0
# 46                     Mushrooms          1      1       1          0
# 51                  Orange juice          1      0       0          0
# 48         Sweet Potatoes cooked          1      1       0          0
# 53               Oat Bran Cooked          1      0       0          0
#
#      Junk Food  Calories  Fats  Proteins  Iron  Calcium  Sodium  Potassium  \
# 0            0        22   0.2       2.4  0.91     23.0    14.0      224.0
# 119          0        15   0.2       1.6  0.72     60.0    11.0      215.0
# 59           0        31   0.2       1.8  1.03     37.0     6.0      211.0
# 38           0        16   0.2       1.2  0.47      5.0    42.0      212.0
# 64           0        32   0.3       0.7  0.41     16.0     1.0      153.0
# 15           0        40   0.1       1.1  0.21     23.0     4.0      146.0
# 46           0        22   0.3       3.1  0.50      3.0     5.0      318.0
# 51           0        45   0.2       0.7  0.20     11.0     1.0      200.0
# 48           0        76   0.1       1.4  0.72     27.0    27.0      230.0
# 53           0        40   0.9       3.2  0.88     10.0     1.0       92.0
#
#      Carbohydrates  Fibre  VitaminD  Sugars
# 0              4.1    2.0         0    1.30
# 119            2.6    1.8         0    0.70
# 59             7.0    2.7         0    3.30
# 38             3.2    0.9         0    2.63
# 64             7.7    2.0         0    4.90
# 15             9.3    1.7         0    4.20
# 46             3.3    1.0         7    2.00
# 51            10.0    0.2         0    8.40
# 48            18.0    2.5         0    5.70
# 53            11.0    2.6         0    0.00

# %% [markdown]
# ## c) Creating an end to end function

# %%
def scaling(dataframe):
    scaler=StandardScaler()
    prep_data=scaler.fit_transform(dataframe.iloc[:,6:15].to_numpy())
    return prep_data,scaler

def nn_predictor(prep_data):
    neigh = NearestNeighbors(metric='cosine',algorithm='brute')
    neigh.fit(prep_data)
    return neigh

def build_pipeline(neigh,scaler,params):
    transformer = FunctionTransformer(neigh.kneighbors,kw_args=params)
    pipeline=Pipeline([('std_scaler',scaler),('NN',transformer)])
    return pipeline

def extract_data(dataframe,ingredient_filter,max_nutritional_values):
    extracted_data=dataframe.copy()
    for column,maximum in zip(extracted_data.columns[6:15],max_nutritional_values):
        extracted_data=extracted_data[extracted_data[column]<maximum]
    if ingredient_filter!=None:
        for ingredient in ingredient_filter:
            extracted_data=extracted_data[extracted_data['RecipeIngredientParts'].str.contains(ingredient,regex=False)] 
    return extracted_data

def apply_pipeline(pipeline,_input,extracted_data):
    return extracted_data.iloc[pipeline.transform(_input)[0]]

def recommand(dataframe,_input,max_nutritional_values,ingredient_filter=None,params={'return_distance':False}):
    extracted_data=extract_data(dataframe,ingredient_filter,max_nutritional_values)
    prep_data,scaler=scaling(extracted_data)
    neigh=nn_predictor(prep_data)
    pipeline=build_pipeline(neigh,scaler,params)
    return apply_pipeline(pipeline,_input,extracted_data)

# %%
test_input=extracted_data.iloc[0:1,6:15].to_numpy()
recommand(dataset,test_input,max_list)
# Out:
#                       Food_items  Breakfast  Lunch  Dinner  VegNovVeg  \
# 0               Asparagus Cooked          0      1       1          0
# 119  Mustard Green(Rayo ko sagg)          0      1       1          0
# 59                         Beans          0      1       1          0
# 38                        Tomato          1      1       1          0
# 64                  Strawberries          1      0       0          0
#
#      Junk Food  Calories  Fats  Proteins  Iron  Calcium  Sodium  Potassium  \
# 0            0        22   0.2       2.4  0.91     23.0    14.0      224.0
# 119          0        15   0.2       1.6  0.72     60.0    11.0      215.0
# 59           0        31   0.2       1.8  1.03     37.0     6.0      211.0
# 38           0        16   0.2       1.2  0.47      5.0    42.0      212.0
# 64           0        32   0.3       0.7  0.41     16.0     1.0      153.0
#
#      Carbohydrates  Fibre  VitaminD  Sugars
# 0              4.1    2.0         0    1.30
# 119            2.6    1.8         0    0.70
# 59             7.0    2.7         0    3.30
# 38             3.2    0.9         0    2.63
# 64             7.7    2.0         0    4.90

# %% [markdown]
# # 6. Saving the data

# %%
df.to_csv('Data_Sets/filtered_data.csv',index=False)
